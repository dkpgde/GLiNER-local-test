# %% [markdown]
# # GLiNER error analysis
# First run `python -m src.error_analysis <prediction.jsonl>`. Review at least 50 false negatives and 50 false positives, then fill `category`, `material_impact`, and `notes`. Suggested categories are in the benchmark plan.

# %%
import pandas as pd
errors = pd.read_csv('../results/error_analysis.csv')
errors.groupby(['error_type', 'label']).size().sort_values(ascending=False).head(30)

# %%
errors.sample(min(20, len(errors)), random_state=42)
